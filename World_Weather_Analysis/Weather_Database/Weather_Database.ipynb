# %%
# Import dependencies and citypy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit
import json
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Perform API Call
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=413b560cfb0f5e104d26d66b0f18db6a

# %%
# Retreiving info from challenge in module

#Weather data list
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jalu
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | kuching
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | yerbogachen
# Processing Record 7 of Set 1 | utete
# Processing Record 8 of Set 1 | monteagudo
# Processing Record 9 of Set 1 | buraydah
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | mount gambier
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | presidente medici
# Processing Record 14 of Set 1 | gerash
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | rivers
# Processing Record 17 of Set 1 | saint-ambroise
# Processing Record 18 of Set 1 | bowen
# Processing Record 19 of Set 1 | constitucion
# Processing Record 20 of Set 1 | gat
# Processing Record 21 of Set 1 | el alto
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | ostrovnoy
# Processing Record 25 of Set 1 | ilulissat
# Processing Record 26 of Set 1 | inirida
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | karaton
# Processing Record 29 of Set 1 | torres
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | manuk mangkaw
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | ust-barguzin
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | ambon
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | isangel
# Processing Record 39 of Set 1 | miandrivazo
# Processing Record 40 of Set 1 | kuytun
# Processing Record 41 of Set 1 | fortuna
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | kalmunai
# Processing Record 44 of Set 1 | bushehr
# Processing Record 45 of Set 1 | krasnoselkup
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | banda aceh
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | sao joao da barra
# Processing Record 50 of Set 1 | hede
# Processing Record 1 of Set 2 | caravelas
# Processing Record 2 of Set 2 | havre-saint-pierre
# Processing Record 3 of Set 2 | alice springs
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | santa vitoria do palmar
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | urengoy
# Processing Record 11 of Set 2 | virginia beach
# Processing Record 12 of Set 2 | coquimbo
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | kutum
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | zhangye
# Processing Record 20 of Set 2 | zonguldak
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | samarai
# Processing Record 23 of Set 2 | yar-sale
# Processing Record 24 of Set 2 | ormara
# Processing Record 25 of Set 2 | coatlan
# City not found. Skipping...
# Processing Record 26 of Set 2 | arrigorriaga
# Processing Record 27 of Set 2 | hasaki
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | acapulco
# Processing Record 30 of Set 2 | lincoln
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | salym
# Processing Record 33 of Set 2 | nelson bay
# Processing Record 34 of Set 2 | belmonte
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | flinders
# Processing Record 39 of Set 2 | kapoeta
# Processing Record 40 of Set 2 | harer
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | yeppoon
# Processing Record 43 of Set 2 | srednekolymsk
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | nanortalik
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | berlin
# Processing Record 48 of Set 2 | ewa beach
# Processing Record 49 of Set 2 | luderitz
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | tubuala
# Processing Record 3 of Set 3 | port augusta
# Processing Record 4 of Set 3 | sitio novo do tocantins
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | porto velho
# Processing Record 7 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 3 | solwezi
# Processing Record 9 of Set 3 | port-gentil
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | collie
# Processing Record 12 of Set 3 | gizo
# Processing Record 13 of Set 3 | tuatapere
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 3 | san juan
# Processing Record 17 of Set 3 | vestmannaeyjar
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | quatre cocos
# Processing Record 20 of Set 3 | talawdi
# City not found. Skipping...
# Processing Record 21 of Set 3 | neiafu
# Processing Record 22 of Set 3 | inhambane
# Processing Record 23 of Set 3 | namatanai
# Processing Record 24 of Set 3 | saldanha
# Processing Record 25 of Set 3 | doha
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | bambous virieux
# Processing Record 29 of Set 3 | victoria
# Processing Record 30 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | jiaohe
# Processing Record 33 of Set 3 | bolobo
# Processing Record 34 of Set 3 | nsanje
# Processing Record 35 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 3 | jhinjhak
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | rio gallegos
# Processing Record 43 of Set 3 | quelimane
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | aniva
# Processing Record 46 of Set 3 | paamiut
# Processing Record 47 of Set 3 | mabaruma
# Processing Record 48 of Set 3 | dauphin
# Processing Record 49 of Set 3 | beringovskiy
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | waingapu
# Processing Record 3 of Set 4 | kharp
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | san cristobal
# Processing Record 6 of Set 4 | kapaa
# Processing Record 7 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 4 | razumnoye
# Processing Record 9 of Set 4 | russell
# Processing Record 10 of Set 4 | mbala
# Processing Record 11 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 4 | talnakh
# Processing Record 15 of Set 4 | yellowknife
# Processing Record 16 of Set 4 | dingle
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | dikson
# Processing Record 19 of Set 4 | kungurtug
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | buchanan
# Processing Record 24 of Set 4 | antalaha
# Processing Record 25 of Set 4 | nouadhibou
# Processing Record 26 of Set 4 | lasa
# Processing Record 27 of Set 4 | kirakira
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | rio cuarto
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | keti bandar
# Processing Record 33 of Set 4 | sinnamary
# Processing Record 34 of Set 4 | khomeynishahr
# City not found. Skipping...
# Processing Record 35 of Set 4 | tomatlan
# Processing Record 36 of Set 4 | najran
# Processing Record 37 of Set 4 | luau
# Processing Record 38 of Set 4 | kohima
# Processing Record 39 of Set 4 | itoman
# Processing Record 40 of Set 4 | sao sebastiao
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | champerico
# Processing Record 43 of Set 4 | turukhansk
# Processing Record 44 of Set 4 | santa comba
# Processing Record 45 of Set 4 | carnarvon
# Processing Record 46 of Set 4 | kibondo
# Processing Record 47 of Set 4 | camargo
# Processing Record 48 of Set 4 | do gonbadan
# Processing Record 49 of Set 4 | kesova gora
# Processing Record 50 of Set 4 | touros
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | lebu
# Processing Record 3 of Set 5 | hervey bay
# Processing Record 4 of Set 5 | dunedin
# Processing Record 5 of Set 5 | krasnaya gorbatka
# Processing Record 6 of Set 5 | suwalki
# Processing Record 7 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 8 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 5 | luanda
# Processing Record 10 of Set 5 | yumen
# Processing Record 11 of Set 5 | mapiripan
# Processing Record 12 of Set 5 | sitka
# Processing Record 13 of Set 5 | saint-gaudens
# Processing Record 14 of Set 5 | annau
# Processing Record 15 of Set 5 | kemijarvi
# Processing Record 16 of Set 5 | kiunga
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | dali
# Processing Record 19 of Set 5 | fayetteville
# Processing Record 20 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | krasnyy yar
# Processing Record 23 of Set 5 | kudahuvadhoo
# Processing Record 24 of Set 5 | lozuvatka
# Processing Record 25 of Set 5 | raga
# Processing Record 26 of Set 5 | lufilufi
# Processing Record 27 of Set 5 | ancud
# Processing Record 28 of Set 5 | kahului
# Processing Record 29 of Set 5 | puerto ayora
# Processing Record 30 of Set 5 | fukue
# Processing Record 31 of Set 5 | hay river
# Processing Record 32 of Set 5 | aksu
# Processing Record 33 of Set 5 | betioky
# Processing Record 34 of Set 5 | ambulu
# Processing Record 35 of Set 5 | matagami
# Processing Record 36 of Set 5 | saint-augustin
# Processing Record 37 of Set 5 | maceio
# Processing Record 38 of Set 5 | hami
# Processing Record 39 of Set 5 | saryozek
# Processing Record 40 of Set 5 | hobyo
# Processing Record 41 of Set 5 | hastings
# Processing Record 42 of Set 5 | cabo san lucas
# Processing Record 43 of Set 5 | wajid
# Processing Record 44 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 5 | morehead
# Processing Record 46 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 5 | daru
# Processing Record 49 of Set 5 | puerto ayacucho
# Processing Record 50 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 6 | kroya
# Processing Record 2 of Set 6 | college
# Processing Record 3 of Set 6 | hualmay
# Processing Record 4 of Set 6 | marienburg
# Processing Record 5 of Set 6 | vila franca do campo
# Processing Record 6 of Set 6 | owensboro
# Processing Record 7 of Set 6 | nuuk
# Processing Record 8 of Set 6 | chumikan
# Processing Record 9 of Set 6 | jumla
# Processing Record 10 of Set 6 | gayeri
# Processing Record 11 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 6 | koumac
# Processing Record 13 of Set 6 | ambo
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | sosnovo-ozerskoye
# Processing Record 16 of Set 6 | semenyih
# Processing Record 17 of Set 6 | labuhan
# Processing Record 18 of Set 6 | sur
# Processing Record 19 of Set 6 | callaway
# Processing Record 20 of Set 6 | hilo
# Processing Record 21 of Set 6 | kyra
# Processing Record 22 of Set 6 | beloha
# Processing Record 23 of Set 6 | santa isabel
# Processing Record 24 of Set 6 | padang
# Processing Record 25 of Set 6 | cairns
# Processing Record 26 of Set 6 | cedro
# Processing Record 27 of Set 6 | xihe
# Processing Record 28 of Set 6 | lovington
# Processing Record 29 of Set 6 | souillac
# Processing Record 30 of Set 6 | sorland
# Processing Record 31 of Set 6 | kushmurun
# Processing Record 32 of Set 6 | kashirskoye
# Processing Record 33 of Set 6 | arys
# Processing Record 34 of Set 6 | ozernovskiy
# Processing Record 35 of Set 6 | comodoro rivadavia
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | kita
# Processing Record 38 of Set 6 | mnogovershinnyy
# Processing Record 39 of Set 6 | sao filipe
# Processing Record 40 of Set 6 | hermanus
# Processing Record 41 of Set 6 | bundaberg
# Processing Record 42 of Set 6 | pitimbu
# Processing Record 43 of Set 6 | kiruna
# Processing Record 44 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | itarema
# Processing Record 47 of Set 6 | muzhi
# Processing Record 48 of Set 6 | atar
# Processing Record 49 of Set 6 | elko
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 1 of Set 7 | centenario do sul
# Processing Record 2 of Set 7 | ucluelet
# Processing Record 3 of Set 7 | fallon
# Processing Record 4 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 7 | high prairie
# Processing Record 6 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 7 | arcata
# Processing Record 9 of Set 7 | cuiluan
# Processing Record 10 of Set 7 | rio tercero
# Processing Record 11 of Set 7 | zhigansk
# Processing Record 12 of Set 7 | leh
# Processing Record 13 of Set 7 | grindavik
# Processing Record 14 of Set 7 | paramonga
# Processing Record 15 of Set 7 | borovskoy
# Processing Record 16 of Set 7 | ekibastuz
# Processing Record 17 of Set 7 | nemuro
# Processing Record 18 of Set 7 | longyearbyen
# Processing Record 19 of Set 7 | cherskiy
# Processing Record 20 of Set 7 | poum
# Processing Record 21 of Set 7 | tiksi
# Processing Record 22 of Set 7 | meulaboh
# Processing Record 23 of Set 7 | chancay
# Processing Record 24 of Set 7 | launceston
# Processing Record 25 of Set 7 | palmer
# Processing Record 26 of Set 7 | meridian
# Processing Record 27 of Set 7 | benguela
# Processing Record 28 of Set 7 | zhob
# Processing Record 29 of Set 7 | trairi
# Processing Record 30 of Set 7 | kargasok
# Processing Record 31 of Set 7 | saurimo
# Processing Record 32 of Set 7 | koungheul
# Processing Record 33 of Set 7 | sola
# Processing Record 34 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 7 | muchkapskiy
# Processing Record 36 of Set 7 | lavrentiya
# Processing Record 37 of Set 7 | kosa
# Processing Record 38 of Set 7 | kupang
# Processing Record 39 of Set 7 | la ronge
# Processing Record 40 of Set 7 | bandarbeyla
# Processing Record 41 of Set 7 | maniitsoq
# Processing Record 42 of Set 7 | iwanai
# Processing Record 43 of Set 7 | pavino
# Processing Record 44 of Set 7 | panacan
# Processing Record 45 of Set 7 | baiyin
# Processing Record 46 of Set 7 | storforshei
# Processing Record 47 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 7 | cap malheureux
# Processing Record 49 of Set 7 | khuzdar
# Processing Record 50 of Set 7 | maragogi
# Processing Record 1 of Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 2 of Set 8 | lenki
# City not found. Skipping...
# Processing Record 3 of Set 8 | san rafael
# Processing Record 4 of Set 8 | marsh harbour
# Processing Record 5 of Set 8 | rostovka
# Processing Record 6 of Set 8 | nacogdoches
# Processing Record 7 of Set 8 | xichang
# Processing Record 8 of Set 8 | chara
# Processing Record 9 of Set 8 | sioux lookout
# Processing Record 10 of Set 8 | katsuura
# Processing Record 11 of Set 8 | port keats
# Processing Record 12 of Set 8 | saint-leu
# Processing Record 13 of Set 8 | lata
# Processing Record 14 of Set 8 | marsaxlokk
# Processing Record 15 of Set 8 | vostok
# Processing Record 16 of Set 8 | ponta delgada
# Processing Record 17 of Set 8 | baykit
# Processing Record 18 of Set 8 | sesquile
# Processing Record 19 of Set 8 | oneonta
# Processing Record 20 of Set 8 | vila velha
# Processing Record 21 of Set 8 | lorengau
# Processing Record 22 of Set 8 | asau
# Processing Record 23 of Set 8 | nushki
# Processing Record 24 of Set 8 | berdyuzhye
# City not found. Skipping...
# Processing Record 25 of Set 8 | bar harbor
# Processing Record 26 of Set 8 | batemans bay
# Processing Record 27 of Set 8 | komsomolskiy
# Processing Record 28 of Set 8 | santa cruz del sur
# Processing Record 29 of Set 8 | leningradskiy
# Processing Record 30 of Set 8 | port blair
# Processing Record 31 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 33 of Set 8 | bilibino
# Processing Record 34 of Set 8 | bria
# Processing Record 35 of Set 8 | hamina
# Processing Record 36 of Set 8 | mattru
# Processing Record 37 of Set 8 | pisco
# Processing Record 38 of Set 8 | qui nhon
# Processing Record 39 of Set 8 | shchuchye
# City not found. Skipping...
# Processing Record 40 of Set 8 | hamilton
# Processing Record 41 of Set 8 | todos santos
# Processing Record 42 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 8 | tiarei
# Processing Record 44 of Set 8 | jardim
# Processing Record 45 of Set 8 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 46 of Set 8 | waipawa
# Processing Record 47 of Set 8 | rio grande
# Processing Record 48 of Set 8 | sao miguel do araguaia
# Processing Record 49 of Set 8 | adrar
# Processing Record 50 of Set 8 | bardiyah
# Processing Record 1 of Set 9 | farafangana
# Processing Record 2 of Set 9 | bara
# Processing Record 3 of Set 9 | skiros
# City not found. Skipping...
# Processing Record 4 of Set 9 | burica
# City not found. Skipping...
# Processing Record 5 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 6 of Set 9 | kruisfontein
# Processing Record 7 of Set 9 | vila
# Processing Record 8 of Set 9 | itaqui
# Processing Record 9 of Set 9 | grand baie
# Processing Record 10 of Set 9 | billings
# Processing Record 11 of Set 9 | kurilsk
# Processing Record 12 of Set 9 | radcliff
# Processing Record 13 of Set 9 | san vicente
# Processing Record 14 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 15 of Set 9 | margate
# Processing Record 16 of Set 9 | banyo
# Processing Record 17 of Set 9 | mana
# Processing Record 18 of Set 9 | bonavista
# Processing Record 19 of Set 9 | alta
# Processing Record 20 of Set 9 | ixtapa
# Processing Record 21 of Set 9 | killin
# Processing Record 22 of Set 9 | bulawayo
# Processing Record 23 of Set 9 | umea
# Processing Record 24 of Set 9 | hovd
# Processing Record 25 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 26 of Set 9 | esperance
# Processing Record 27 of Set 9 | saint-louis
# Processing Record 28 of Set 9 | bilma
# Processing Record 29 of Set 9 | grants
# Processing Record 30 of Set 9 | alto araguaia
# Processing Record 31 of Set 9 | alappuzha
# Processing Record 32 of Set 9 | grand gaube
# Processing Record 33 of Set 9 | saint-francois
# Processing Record 34 of Set 9 | juba
# Processing Record 35 of Set 9 | auki
# Processing Record 36 of Set 9 | izhma
# Processing Record 37 of Set 9 | nyurba
# Processing Record 38 of Set 9 | simao
# Processing Record 39 of Set 9 | uong bi
# Processing Record 40 of Set 9 | rantepao
# Processing Record 41 of Set 9 | birjand
# Processing Record 42 of Set 9 | husavik
# Processing Record 43 of Set 9 | cayenne
# Processing Record 44 of Set 9 | liverpool
# Processing Record 45 of Set 9 | pangody
# Processing Record 46 of Set 9 | clarence town
# Processing Record 47 of Set 9 | haines junction
# Processing Record 48 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 9 | campos belos
# Processing Record 50 of Set 9 | henties bay
# Processing Record 1 of Set 10 | watsa
# Processing Record 2 of Set 10 | svetlogorsk
# Processing Record 3 of Set 10 | axim
# Processing Record 4 of Set 10 | canosa di puglia
# Processing Record 5 of Set 10 | emilio carranza
# Processing Record 6 of Set 10 | mokhsogollokh
# Processing Record 7 of Set 10 | meybod
# Processing Record 8 of Set 10 | erzin
# Processing Record 9 of Set 10 | fort frances
# Processing Record 10 of Set 10 | horta
# Processing Record 11 of Set 10 | turkan
# Processing Record 12 of Set 10 | nerchinskiy zavod
# Processing Record 13 of Set 10 | saint-pierre
# Processing Record 14 of Set 10 | naze
# Processing Record 15 of Set 10 | mao
# Processing Record 16 of Set 10 | mandalgovi
# Processing Record 17 of Set 10 | nizwa
# Processing Record 18 of Set 10 | celestun
# Processing Record 19 of Set 10 | oistins
# Processing Record 20 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 21 of Set 10 | necochea
# Processing Record 22 of Set 10 | marfino
# Processing Record 23 of Set 10 | marsa matruh
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | turayf
# Processing Record 26 of Set 10 | bahia blanca
# Processing Record 27 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 10 | geraldton
# Processing Record 29 of Set 10 | kondinskoye
# Processing Record 30 of Set 10 | taltal
# Processing Record 31 of Set 10 | santa cruz del norte
# Processing Record 32 of Set 10 | kenai
# Processing Record 33 of Set 10 | sigli
# Processing Record 34 of Set 10 | vilhena
# Processing Record 35 of Set 10 | juneau
# Processing Record 36 of Set 10 | tucuman
# Processing Record 37 of Set 10 | vardo
# Processing Record 38 of Set 10 | kawalu
# Processing Record 39 of Set 10 | wanning
# Processing Record 40 of Set 10 | general pico
# Processing Record 41 of Set 10 | phan thiet
# Processing Record 42 of Set 10 | praia
# Processing Record 43 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 10 | endicott
# Processing Record 45 of Set 10 | ligayan
# Processing Record 46 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 47 of Set 10 | konstantinovka
# Processing Record 48 of Set 10 | bell ville
# Processing Record 49 of Set 10 | sabha
# Processing Record 50 of Set 10 | bassar
# Processing Record 1 of Set 11 | coihaique
# Processing Record 2 of Set 11 | sisimiut
# Processing Record 3 of Set 11 | deputatskiy
# Processing Record 4 of Set 11 | manokwari
# Processing Record 5 of Set 11 | pangai
# Processing Record 6 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 11 | burgeo
# Processing Record 8 of Set 11 | portland
# Processing Record 9 of Set 11 | west wendover
# Processing Record 10 of Set 11 | tabukiniberu
# City not found. Skipping...
# Processing Record 11 of Set 11 | tulu bolo
# Processing Record 12 of Set 11 | nabire
# Processing Record 13 of Set 11 | koster
# Processing Record 14 of Set 11 | flin flon
# Processing Record 15 of Set 11 | yongchang
# Processing Record 16 of Set 11 | derzhavinsk
# Processing Record 17 of Set 11 | mut
# Processing Record 18 of Set 11 | kavaratti
# Processing Record 19 of Set 11 | garango
# Processing Record 20 of Set 11 | barra patuca
# Processing Record 21 of Set 11 | lensk
# Processing Record 22 of Set 11 | cap-aux-meules
# Processing Record 23 of Set 11 | tete
# Processing Record 24 of Set 11 | avera
# Processing Record 25 of Set 11 | moussoro
# Processing Record 26 of Set 11 | puerto cortes
# City not found. Skipping...
# Processing Record 27 of Set 11 | prado
# Processing Record 28 of Set 11 | nantucket
# Processing Record 29 of Set 11 | innisfail
# Processing Record 30 of Set 11 | asmara
# Processing Record 31 of Set 11 | nedjo
# Processing Record 32 of Set 11 | byron bay
# Processing Record 33 of Set 11 | sao tome
# Processing Record 34 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 11 | itabira
# Processing Record 36 of Set 11 | dhidhdhoo
# Processing Record 37 of Set 11 | lokosovo
# Processing Record 38 of Set 11 | ilesha
# Processing Record 39 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 11 | sarangani
# Processing Record 41 of Set 11 | severo-kurilsk
# Processing Record 42 of Set 11 | piacabucu
# Processing Record 43 of Set 11 | kotido
# Processing Record 44 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 11 | kloulklubed
# Processing Record 46 of Set 11 | sumbawanga
# Processing Record 47 of Set 11 | igarka
# Processing Record 48 of Set 11 | manzanillo
# Processing Record 49 of Set 11 | bogande
# Processing Record 50 of Set 11 | teya
# Processing Record 1 of Set 12 | kurumkan
# Processing Record 2 of Set 12 | jiaxing
# Processing Record 3 of Set 12 | aykhal
# Processing Record 4 of Set 12 | carahue
# Processing Record 5 of Set 12 | sadri
# Processing Record 6 of Set 12 | bathsheba
# Processing Record 7 of Set 12 | lakes entrance
# Processing Record 8 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 9 of Set 12 | okha
# Processing Record 10 of Set 12 | broome
# Processing Record 11 of Set 12 | richards bay
# Processing Record 12 of Set 12 | emerald
# Processing Record 13 of Set 12 | gigmoto
# Processing Record 14 of Set 12 | northam
# Processing Record 15 of Set 12 | banjar
# Processing Record 16 of Set 12 | kautokeino
# Processing Record 17 of Set 12 | timaru
# Processing Record 18 of Set 12 | chanika
# Processing Record 19 of Set 12 | westport
# Processing Record 20 of Set 12 | lokoja
# Processing Record 21 of Set 12 | muisne
# Processing Record 22 of Set 12 | nouakchott
# Processing Record 23 of Set 12 | zhezkazgan
# Processing Record 24 of Set 12 | baglan
# Processing Record 25 of Set 12 | san luis
# Processing Record 26 of Set 12 | kampene
# Processing Record 27 of Set 12 | quang ngai
# Processing Record 28 of Set 12 | the valley
# Processing Record 29 of Set 12 | bratsk
# Processing Record 30 of Set 12 | mangaratiba
# Processing Record 31 of Set 12 | nome
# Processing Record 32 of Set 12 | pimentel
# Processing Record 33 of Set 12 | tura
# Processing Record 34 of Set 12 | mahibadhoo
# Processing Record 35 of Set 12 | rawson
# Processing Record 36 of Set 12 | alfeld
# Processing Record 37 of Set 12 | wenling
# Processing Record 38 of Set 12 | anadyr
# Processing Record 39 of Set 12 | asfi
# Processing Record 40 of Set 12 | zhangjiakou
# Processing Record 41 of Set 12 | awjilah
# Processing Record 42 of Set 12 | mount isa
# Processing Record 43 of Set 12 | vung tau
# Processing Record 44 of Set 12 | belyy yar
# Processing Record 45 of Set 12 | coahuayana
# Processing Record 46 of Set 12 | kedrovyy
# Processing Record 47 of Set 12 | arrah
# Processing Record 48 of Set 12 | palu
# Processing Record 49 of Set 12 | zhaoyang
# Processing Record 50 of Set 12 | hirara
# Processing Record 1 of Set 13 | santa marta
# Processing Record 2 of Set 13 | sept-iles
# Processing Record 3 of Set 13 | elizabeth city
# Processing Record 4 of Set 13 | casma
# Processing Record 5 of Set 13 | morant bay
# Processing Record 6 of Set 13 | san quintin
# Processing Record 7 of Set 13 | pangnirtung
# Processing Record 8 of Set 13 | tres pontas
# Processing Record 9 of Set 13 | madang
# Processing Record 10 of Set 13 | port lincoln
# Processing Record 11 of Set 13 | san matias
# Processing Record 12 of Set 13 | puerto del rosario
# Processing Record 13 of Set 13 | faya
# Processing Record 14 of Set 13 | waterfoot
# Processing Record 15 of Set 13 | laguna
# Processing Record 16 of Set 13 | matata
# Processing Record 17 of Set 13 | shubarshi
# Processing Record 18 of Set 13 | bulungu
# Processing Record 19 of Set 13 | new richmond
# Processing Record 20 of Set 13 | carbondale
# Processing Record 21 of Set 13 | jizan
# Processing Record 22 of Set 13 | khani
# Processing Record 23 of Set 13 | ulladulla
# Processing Record 24 of Set 13 | buribay
# Processing Record 25 of Set 13 | ahipara
# Processing Record 26 of Set 13 | vetluga
# Processing Record 27 of Set 13 | tangwani
# Processing Record 28 of Set 13 | karratha
# Processing Record 29 of Set 13 | eyl
# Processing Record 30 of Set 13 | nobeoka
# Processing Record 31 of Set 13 | birin
# Processing Record 32 of Set 13 | bridlington
# Processing Record 33 of Set 13 | teguise
# Processing Record 34 of Set 13 | carutapera
# Processing Record 35 of Set 13 | sawakin
# Processing Record 36 of Set 13 | buin
# Processing Record 37 of Set 13 | omsukchan
# Processing Record 38 of Set 13 | narsaq
# Processing Record 39 of Set 13 | abbeville
# Processing Record 40 of Set 13 | zyryanka
# Processing Record 41 of Set 13 | balakhta
# Processing Record 42 of Set 13 | lafia
# Processing Record 43 of Set 13 | uyemskiy
# Processing Record 44 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 13 | nong khai
# Processing Record 46 of Set 13 | pareora
# Processing Record 47 of Set 13 | vacaria
# Processing Record 48 of Set 13 | brainerd
# Processing Record 49 of Set 13 | lahij
# Processing Record 50 of Set 13 | alpena
# Processing Record 1 of Set 14 | maine-soroa
# Processing Record 2 of Set 14 | batagay-alyta
# Processing Record 3 of Set 14 | bud
# Processing Record 4 of Set 14 | santa lucia
# Processing Record 5 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 14 | lhokseumawe
# Processing Record 7 of Set 14 | high level
# Processing Record 8 of Set 14 | belgrade
# Processing Record 9 of Set 14 | slanic-moldova
# Processing Record 10 of Set 14 | warrnambool
# Processing Record 11 of Set 14 | paragominas
# Processing Record 12 of Set 14 | gjusvik
# City not found. Skipping...
# Processing Record 13 of Set 14 | los llanos de aridane
# Processing Record 14 of Set 14 | alugan
# Processing Record 15 of Set 14 | hondo
# Processing Record 16 of Set 14 | odweyne
# Processing Record 17 of Set 14 | nago
# Processing Record 18 of Set 14 | illapel
# Processing Record 19 of Set 14 | lubsko
# Processing Record 20 of Set 14 | verkhnetulomskiy
# Processing Record 21 of Set 14 | humberto de campos
# Processing Record 22 of Set 14 | lima duarte
# Processing Record 23 of Set 14 | plouzane
# Processing Record 24 of Set 14 | erzurum
# Processing Record 25 of Set 14 | zharkent
# Processing Record 26 of Set 14 | unye
# City not found. Skipping...
# Processing Record 27 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 28 of Set 14 | benalla
# Processing Record 29 of Set 14 | ust-tsilma
# Processing Record 30 of Set 14 | yarega
# Processing Record 31 of Set 14 | igrim
# Processing Record 32 of Set 14 | kihei
# Processing Record 33 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 14 | ayna
# Processing Record 35 of Set 14 | priego de cordoba
# Processing Record 36 of Set 14 | adelaide
# Processing Record 37 of Set 14 | saint anthony
# Processing Record 38 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 39 of Set 14 | madarounfa
# Processing Record 40 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 14 | takoradi
# Processing Record 42 of Set 14 | ajdabiya
# Processing Record 43 of Set 14 | borogontsy
# Processing Record 44 of Set 14 | kuusamo
# Processing Record 45 of Set 14 | yulara
# Processing Record 46 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 14 | port-cartier
# Processing Record 48 of Set 14 | port hardy
# Processing Record 49 of Set 14 | paracuru
# Processing Record 50 of Set 14 | cordoba
# Processing Record 1 of Set 15 | verkhoyansk
# Processing Record 2 of Set 15 | la tuque
# Processing Record 3 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 15 | aripuana
# Processing Record 5 of Set 15 | mosquera
# Processing Record 6 of Set 15 | roebourne
# Processing Record 7 of Set 15 | abu kamal
# Processing Record 8 of Set 15 | verkhniy baskunchak
# Processing Record 9 of Set 15 | san andres
# Processing Record 10 of Set 15 | donskoye
# Processing Record 11 of Set 15 | lingao
# Processing Record 12 of Set 15 | tekeli
# Processing Record 13 of Set 15 | trelew
# Processing Record 14 of Set 15 | arinos
# Processing Record 15 of Set 15 | ryde
# Processing Record 16 of Set 15 | davidson
# Processing Record 17 of Set 15 | santa maria
# Processing Record 18 of Set 15 | glendive
# Processing Record 19 of Set 15 | katakwi
# Processing Record 20 of Set 15 | acari
# Processing Record 21 of Set 15 | carira
# Processing Record 22 of Set 15 | severnyy
# Processing Record 23 of Set 15 | katherine
# Processing Record 24 of Set 15 | ocos
# Processing Record 25 of Set 15 | brora
# Processing Record 26 of Set 15 | saint-quentin
# Processing Record 27 of Set 15 | angoche
# Processing Record 28 of Set 15 | vao
# Processing Record 29 of Set 15 | wewak
# Processing Record 30 of Set 15 | novodugino
# Processing Record 31 of Set 15 | zhengjiatun
# Processing Record 32 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 33 of Set 15 | pauini
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 667

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Jalu      LY  29.0331   21.5482     85.50        10           0
# 1       Rikitea      PF -23.1203 -134.9692     76.17        64          45
# 2       Kuching      MY   1.5500  110.3333     77.22       100          40
# 3  Punta Arenas      CL -53.1500  -70.9167     44.11        70          25
# 4    Nikolskoye      RU  59.7035   30.7861     31.91        95          71
#
#    Wind Speed Current Description
# 0       10.58           clear sky
# 1        8.79    scattered clouds
# 2        0.00    scattered clouds
# 3       26.91    scattered clouds
# 4        1.63       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
